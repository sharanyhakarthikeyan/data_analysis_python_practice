# %%
df = pd.read_csv("data/income_1.csv")
df.head(10)
# Out:
#        name  salaray  log_values
# 0      raja     1200    3.079181
# 1      suma     2900    3.462398
# 2      ragu    34800    4.541579
# 3  karishma     1240    3.093422
# 4   kavitha      850    2.929419
# 5      velu     1050    3.021189

# %%
import pandas as pd

df = pd.read_csv("data/income_1.csv")
df.plot(x='name', y='salaray', kind='bar')
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
#  The salaray data set has different margins of salaray scale which is hard to compare. Foe resolving the skew between bars, Log scale solves the issue for the proper varience visualisation.

# %%
import pandas as pd

df = pd.read_csv("data/income_1.csv")
df.plot(x='name', y='salaray', kind='bar', log =True)
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# I used log values in the table which help to visualize the data clearly.

# %%
import pandas as pd

df = pd.read_csv("data/income_1.csv")
df.plot(x='name', y='log_values', kind='pie')
# Out:
# <AxesSubplot:ylabel='log_values'>

# %%
import pandas as pd

df = pd.read_csv("data/income_1.csv")
df.plot(x='name', y='log_values', kind='line')
# Out:
# <AxesSubplot:xlabel='name'>
